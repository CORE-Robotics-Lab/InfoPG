# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
with open(os.path.join('experiments', 'pr2', '2021-07-26 03_59_48', 'data.npy'), 'rb') as f:
    data = np.load(f)

fig, ax = plt.subplots(1, 2, figsize=(30,10))
ax[0].plot(np.arange(0, 4000), data[:, 0])
ax[1].plot(np.arange(0, 4000), data[:, 1])
plt.show()

# %%
with open(os.path.join('experiments', 'pr2', '2021-08-07 20_13_32', 'data.npy'), 'rb') as f:
    data = np.load(f)
print(data.shape)
fig, ax = plt.subplots(1, 2, figsize=(30,10))
ax[0].plot(np.arange(0, 4000), data[:, 0, 2])
ax[1].plot(np.arange(0, 4000), data[:, 1, 2])
plt.show()
# Out:
# (4000, 2, 3)
